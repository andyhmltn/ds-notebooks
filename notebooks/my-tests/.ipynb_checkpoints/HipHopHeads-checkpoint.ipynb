# %%
import pandas as pd
import numpy as np
import re

from functools import reduce

def format_title(title):
    title = title.replace('[FRESH] ', '') \
                 .replace('$', '') \
                 .replace('&amp;', '&') \
                 .lower()

    # Filter out anything in brackets
    return re.sub("[\ (\[].*?[\)\]]", "", title)

def format_as_lowercase(artist):
    return artist.lower()

def flair_doesnt_contain_artist_and_title(flair):
    return not (re.search('artist', flair, re.IGNORECASE) and \
           re.search('title', flair, re.IGNORECASE))

def strip_out_featuring(song):
    return re.sub("[ft|FT|feat].([./])+$", "", song)


HHH = pd.read_csv("HHH.csv")
# Filter out unneeded columns
HHH = HHH[['title', 'score', 'link_flair_text']]

# Format title
HHH['title'] = HHH['title'].apply(format_title)
HHH['score'] = HHH['score'].astype('int')

# Filter out all the songs that can't be split exactly in 2 using ' - '
# HHH = HHH[(HHH['title'].str.split(' - ')).apply(len) == 2]

# Filter out all flairs with artist / title in (means the title is formatted incorrectly)
HHH = HHH[HHH['link_flair_text'].apply(flair_doesnt_contain_artist_and_title)]

# Split the title out into an artist & a song
HHH['artist'], HHH['song'] = zip(*HHH['title'].map(lambda x: \
                                                   x.split(' - ') or x))

# Sort by score
HHH = HHH.sort_values(['score'], ascending=[0])
# Get the first 30

x = HHH.head(20)
# Out:
#   File "<ipython-input-1-fd2bbc7f5dce>", line 15
#     def flair_doesnt_contain_artist_and_title(flair):
#       ^
# IndentationError: expected an indented block

# %%
import seaborn as sns


sns.set_style("whitegrid")

g = sns.barplot(x="title", y="score", data={ "title": x['song'].apply(strip_out_featuring), "score": x['score'] },
            label="Alcohol-involved", color="c")

for item in g.get_xticklabels():
    item.set_rotation(90)

for item in g.get_yticklabels():
    item.set_rotation(45)


x_axis = sns.plt.gca().axes.get_xlim()
g.plot(x_axis, len(x_axis) * [HHH['score'].mean()], sns.xkcd_rgb["red"])

g.set(xlabel='', ylabel='')

sns.plt.tight_layout()
sns.plt.savefig('test.pdf', format='pdf') 
sns.plt.show()

# %%
x[:2]['score'].sum() / x['score'].sum()
# Out:
# 0.36590202594061527

# %%
data = {
    "title": HHH["title"],
    "score": HHH["score"],
}

new_hhh = pd.DataFrame(data)

new_hhh['start'], new_hhh['end'] = zip(*new_hhh['title'].map(lambda x: x.split(' - ')))
# new_hhh['title'].str.split(' - ')

# %%
new_hhh
# Out:
#      score                                              title  \
# 0     1304                                Aminé - REDMERCEDES
# 4      182                                   Roy Wood - Right
# 5     2167               Love Galore - SZA feat. Travis Scott
# 6      574                          Waka Flocka - Was My Dawg
# 7     5685         Drake - More Life Now Available On Spotify
# 10    1129                      Big Sean - No More Interviews
# 11     321          Chillin- Nice Shot Hugo - HugS Diss Track
# 12     230                    Joe Budden - Rage & The Machine
# 13    1660  New Level REMIX - AAP Ferg Ft. Future, AAP Roc...
# 15     723                        Drake - Wanna Know ft. Dave
# 16     106  T.I. - Switchin Lanes feat Big K R I T & Trev ...
# 20    4368                        Run the Jewels - Talk to Me
# 22    1889                            Gorillaz - Saturnz Barz
# 24     140  Young Thug - Young Nigga FT. ralo, lil-uzi-ver...
# 50                Joey Fatts Feat. Vince Staples
# 52                                        Future
# 53                                  PARTNEXTDOOR
# 59                                         Logic
# 60                                        Antwon
# 65                                        Sampha
# ..                                           ...
# 203                                     2 Chainz
# 204                                    Fetty Wap
# 206                                  Chiddy Bang
# 209                                       Father
# 211                                       Lunice
# 212   Francis & The Lights ft. Chance The Rapper
# 213                                    DJ Khaled
# 214                                 Travis Scott
# 215                                   Kanye West
# 222                                     30 Hours
# 225                      The Jacka & Richie Rich
# 232                                   Kanye West
# 233                                   Aesop Rock
# 235                                   Riley Reid
# 236                                Stephen Curry
# 239                              Earl Sweatshirt
# 240                              Earl Sweatshirt
# 241          J.U.S.T.I.C.E. League & Kevin Gates
# 244                                      Cam'ron
# 245                      Kanye West Ft. Bon Iver
# 251                      Miguel Ft. Travis Scott
# 252                                        Max B
# 254         Kanye West ft. J.U.S.T.I.C.E. League
# 256                                ILOVEMAKONNEN
# 257                                   YOUNG THUG
# 259                                        Elzhi
# 261                                      Rihanna
# 262                                 Travis Scott
# 263  Eminem & Proof freestyle never heard before
# 267                                   Kanye West
#
#                                                  end
# 0                                        REDMERCEDES
# 4                                              Right
# 5                             SZA feat. Travis Scott
# 6                                        Was My Dawg
# 7                 More Life Now Available On Spotify
# 10                                No More Interviews
# 11                                   HugS Diss Track
# 12                                Rage & The Machine
# 13   AAP Ferg Ft. Future, AAP Rocky and Lil Uzi Vert
# 15                               Wanna Know ft. Dave
# 16       Switchin Lanes feat Big K R I T & Trev Case
# 20                                        Talk to Me
# 22                                      Saturnz Barz
# 24    Young Nigga FT. ralo, lil-uzi-vert, lil-yachty
# 26                                      DROGAS LIGHT
# 29                                  The Heart Part 4
# 33                                    Anticipation 3
# 35                               Hush Up The Silence
# 38                                        私 Noodle❗️
# 39                                  Trappy New Years
# 40                           Halfway Off The Balcony
# 46                                             Slave
# 48                                               '06
# 49                          Daniel Son; Necklace Don
# 50                                         Farrakhan
# 52                                 Bitches Gone Tell
# 53                       "Come and See Me" ft. Drake
# 59                                  Wrist Ft Pusha T
# 60                                              100k
# 65                                     Plastic 100°C
# ..                                               ...
# 203                                    DNA Freestyle
# 204                                              Aye
# 206                                     Been a While
# 209                                            Hands
# 211                'Distrust' featuring Denzel Curry
# 212                            May I Have This Dance
# 213         Wild Thoughts ft. Rihanna, Bryson Tiller
# 214                  Neptune Estate feat. KING Krule
# 215                         All Day/I Feel Like That
# 222                                       Kanye West
# 225                                         Everyday
# 232                                    WOLVES OG CDQ
# 233                                            Rings
# 235                                     8Ball Shawty
# 236                                       Soulja Boy
# 239                                             Bary
# 240                                        SKRT-SKRT
# 241                                   Roaming Around
# 244                                   U Wasn't There
# 245                               Fall Out Of Heaven
# 251                                            Waves
# 252                            Message to Kanye West
# 254                                        Old Kanye
# 256                                        BIG GUCCI
# 257                            NEW YEEZY SEASON SONG
# 259                     coSIGN ft. Skonie by GLOW365
# 261                                             ANTI
# 262                                          Tourist
# 263                          Westwood throwback 1999
# 267                                The Life of Pablo
#
# [119 rows x 4 columns]
